# %%
# %cd ..
# Out:
# /home/zach/dev/ai4all_berkeley_driving

# %%
# %matplotlib inline

# %%
from driving.visualization import *
from driving.env import DrivingEnv
from IPython.display import clear_output

# %%
env = DrivingEnv()

# %%
def policy(x, y, theta_deg):
    d, delta_deg = env.map.distance_angle_deg(x, y, theta_deg)
    return -200*d - 2.0*delta_deg

# %%
anim = animate(env, policy)
clear_output()
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
plot_episode(env, policy)
